# %% [markdown]
# <a href="https://colab.research.google.com/github/hadni17/skripsi/blob/main/MODEL_w_SU_(270323).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install skfeature-chappers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: skfeature-chappers in /usr/local/lib/python3.9/dist-packages (1.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from skfeature-chappers) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from skfeature-chappers) (1.4.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from skfeature-chappers) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->skfeature-chappers) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->skfeature-chappers) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->skfeature-chappers) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->skfeature-chappers) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->skfeature-chappers) (1.10.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->skfeature-chappers) (1.16.0)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
dataset=pd.read_csv('/content/drive/MyDrive/data_olah.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2477 entries, 0 to 2476
# Data columns (total 94 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID_MAHASISWA                2477 non-null   int64
#  1   prodiID                     2477 non-null   int64
#  2   mhsAngk                     2477 non-null   int64
#  3   mhskdprop                   2477 non-null   int64
#  4   mhskdkab                    2477 non-null   int64
#  5   mhskdpos                    2477 non-null   int64
#  6   tempat_lahir                2477 non-null   object
#  7   mhskdtmplhrprop             2477 non-null   int64
#  8   mhskdtmplhrkab              2477 non-null   int64
#  9   mhstgllhr                   2477 non-null   object
#  10  mhsjk                       2477 non-null   int64
#  11  mhsstatrmh                  2477 non-null   int64
#  12  mhswni                      2477 non-null   int64
#  13  mhsjs                       2477 non-null   int64
#  14  mhsstatus                   2477 non-null   int64
#  15  mhstextnoind                2477 non-null   int64
#  16  mhskeg                      2477 non-null   int64
#  17  mhssifatkeg                 2477 non-null   int64
#  18  mhsptslain                  2477 non-null   int64
#  19  mhsagama                    2477 non-null   int64
#  20  mhskawin                    2477 non-null   int64
#  21  mhshoby                     2477 non-null   int64
#  22  mhsgoldarah                 2477 non-null   int64
#  23  mhspdkayah                  2477 non-null   int64
#  24  mhspdkibu                   2477 non-null   int64
#  25  mhspekayah                  2477 non-null   int64
#  26  mhspekibu                   2477 non-null   int64
#  27  mhsjalurmsk                 2477 non-null   int64
#  28  mhshubdgot                  2477 non-null   int64
#  29  mhssmtaasal                 2477 non-null   int64
#  30  mhssmtath                   2477 non-null   int64
#  31  mhssmtakls                  2477 non-null   int64
#  32  mhssmtanoin                 2477 non-null   int64
#  33  mhssttbth                   2477 non-null   int64
#  34  mhssttbmp                   2477 non-null   int64
#  35  mhssttbnilai                2477 non-null   int64
#  36  mhsebtamp                   2477 non-null   int64
#  37  mhsebtanilai                2477 non-null   float64
#  38  mhsthlhrayah                2477 non-null   int64
#  39  mhsthlhribu                 2477 non-null   int64
#  40  mhsbeasiswa                 2477 non-null   int64
#  41  mhssmtajur                  2477 non-null   int64
#  42  mhssmbbiaya                 2477 non-null   int64
#  43  mhswaliprop                 2477 non-null   int64
#  44  mhswalikab                  2477 non-null   int64
#  45  mhsprestasi                 2477 non-null   int64
#  46  mhspemberibeasiswa          2477 non-null   int64
#  47  thlulus                     0 non-null      float64
#  48  pt_asal                     0 non-null      float64
#  49  smt_reg                     0 non-null      float64
#  50  total_kredit_capai          2473 non-null   object
#  51  prodi                       0 non-null      float64
#  52  reg                         2477 non-null   int64
#  53  stat_jenjang                0 non-null      float64
#  54  cek_reg                     0 non-null      float64
#  55  mhs_smta_prop               2477 non-null   int64
#  56  prodi_asal                  0 non-null      float64
#  57  prodi_s2                    0 non-null      float64
#  58  pt_asal_s2                  0 non-null      float64
#  59  nisn                        5 non-null      float64
#  60  npsn                        5 non-null      float64
#  61  penghasilan_ibu             2476 non-null   float64
#  62  penghasilan_ibu_range       2477 non-null   int64
#  63  penghasilan_ayah            2476 non-null   float64
#  64  penghasilan_ayah_range      2477 non-null   int64
#  65  mhsgajiortu                 2477 non-null   int64
#  66  penyakit_diderita           432 non-null    object
#  67  kegiatan_mahasiswa          1107 non-null   object
#  68  ukuran_kaos                 2411 non-null   object
#  69  status_tinggal              90 non-null     float64
#  70  status_ortu_ayah            7 non-null      float64
#  71  status_ortu_ibu             7 non-null      float64
#  72  penghasilan_sampingan_ibu   7 non-null      float64
#  73  penghasilan_sampingan_ayah  7 non-null      float64
#  74  jumlah_tanggungan           7 non-null      float64
#  75  kebangsaan                  0 non-null      float64
#  76  Tanggal_Lahir               2268 non-null   object
#  77  Jenis_Kelamin               2268 non-null   float64
#  78  Angkatan                    2268 non-null   float64
#  79  kode                        2477 non-null   int64
#  80  jenjang                     2477 non-null   int64
#  81  fakult                      2477 non-null   int64
#  82  nama_prodi_asli             2477 non-null   object
#  83  Tanggal_Lulus               2268 non-null   object
#  84  IPS1                        2477 non-null   float64
#  85  IPS2                        2476 non-null   float64
#  86  IPS3                        2476 non-null   float64
#  87  IPS4                        2476 non-null   float64
#  88  total_kredit_capai_smt4     2476 non-null   float64
#  89  IPS5                        2476 non-null   float64
#  90  IPS6                        2468 non-null   float64
#  91  total_kredit_capai_smt6     2447 non-null   float64
#  92  ipk                         2470 non-null   float64
#  93  STATUS DROP OUT             2477 non-null   object
# dtypes: float64(32), int64(52), object(10)
# memory usage: 1.8+ MB

# %%
dataset.columns
# Out:
# Index(['ID_MAHASISWA', 'prodiID', 'mhsAngk', 'mhskdprop', 'mhskdkab',
#        'mhskdpos', 'tempat_lahir', 'mhskdtmplhrprop', 'mhskdtmplhrkab',
#        'mhstgllhr', 'mhsjk', 'mhsstatrmh', 'mhswni', 'mhsjs', 'mhsstatus',
#        'mhstextnoind', 'mhskeg', 'mhssifatkeg', 'mhsptslain', 'mhsagama',
#        'mhskawin', 'mhshoby', 'mhsgoldarah', 'mhspdkayah', 'mhspdkibu',
#        'mhspekayah', 'mhspekibu', 'mhsjalurmsk', 'mhshubdgot', 'mhssmtaasal',
#        'mhssmtath', 'mhssmtakls', 'mhssmtanoin', 'mhssttbth', 'mhssttbmp',
#        'mhssttbnilai', 'mhsebtamp', 'mhsebtanilai', 'mhsthlhrayah',
#        'mhsthlhribu', 'mhsbeasiswa', 'mhssmtajur', 'mhssmbbiaya',
#        'mhswaliprop', 'mhswalikab', 'mhsprestasi', 'mhspemberibeasiswa',
#        'thlulus', 'pt_asal', 'smt_reg', 'total_kredit_capai', 'prodi', 'reg',
#        'stat_jenjang', 'cek_reg', 'mhs_smta_prop', 'prodi_asal', 'prodi_s2',
#        'pt_asal_s2', 'nisn', 'npsn', 'penghasilan_ibu',
#        'penghasilan_ibu_range', 'penghasilan_ayah', 'penghasilan_ayah_range',
#        'mhsgajiortu', 'penyakit_diderita', 'kegiatan_mahasiswa', 'ukuran_kaos',
#        'status_tinggal', 'status_ortu_ayah', 'status_ortu_ibu',
#        'penghasilan_sampingan_ibu', 'penghasilan_sampingan_ayah',
#        'jumlah_tanggungan', 'kebangsaan', 'Tanggal_Lahir', 'Jenis_Kelamin',
#        'Angkatan', 'kode', 'jenjang', 'fakult', 'nama_prodi_asli',
#        'Tanggal_Lulus', 'IPS1', 'IPS2', 'IPS3', 'IPS4',
#        'total_kredit_capai_smt4 ', 'IPS5', 'IPS6', 'total_kredit_capai_smt6 ',
#        'ipk', 'STATUS DROP OUT'],
#       dtype='object')

# %%
dataset['STATUS DROP OUT'] = dataset['STATUS DROP OUT'].replace(to_replace={'TIDAK DROP OUT':0,'DROP OUT':1})
dataset.rename(columns={'STATUS DROP OUT':'class'},inplace=True)
dataset.replace('-', np.nan)
dataset.drop('ID_MAHASISWA',axis=1,inplace=True)
dataset[['kegiatan_mahasiswa', 'penyakit_diderita']]
# Out:
#                    kegiatan_mahasiswa penyakit_diderita
# 0                                 NaN               NaN
# 1                    KSR PMI Unit UNS              maag
# 2     KOPMA UNS & lembaga keanggotaan               NaN
# 3                                 NaN               NaN
# 4                 Kine Klub FISIP UNS               NaN
# ...                               ...               ...
# 2472                              aai      asam lambung
# 2473                              NaN               NaN
# 2474                              NaN               NaN
# 2475                              NaN               NaN
# 2476                              NaN               NaN
#
# [2477 rows x 2 columns]

# %%
dataset['kegiatan_mahasiswa'] = dataset['kegiatan_mahasiswa'].replace([np.nan,'Tidak ada','TIDAK ADA','Tidak Ada'], 'tidak ada')
dataset['penyakit_diderita'] = dataset['penyakit_diderita'].replace([np.nan,'Tidak ada','TIDAK ADA','Tidak Ada'], 'tidak ada')
dataset[['kegiatan_mahasiswa', 'penyakit_diderita']]
# Out:
#                    kegiatan_mahasiswa penyakit_diderita
# 0                           tidak ada         tidak ada
# 1                    KSR PMI Unit UNS              maag
# 2     KOPMA UNS & lembaga keanggotaan         tidak ada
# 3                           tidak ada         tidak ada
# 4                 Kine Klub FISIP UNS         tidak ada
# ...                               ...               ...
# 2472                              aai      asam lambung
# 2473                        tidak ada         tidak ada
# 2474                        tidak ada         tidak ada
# 2475                        tidak ada         tidak ada
# 2476                        tidak ada         tidak ada
#
# [2477 rows x 2 columns]

# %%
dataset.drop(['prodiID',
'mhskdpos',
'mhsjs',
'mhsstatus',
'mhskeg',
'mhssifatkeg',
'mhsptslain',
'mhssttbmp',
'mhssttbnilai',
'thlulus',
'pt_asal',
'smt_reg',
'prodi',
'stat_jenjang',
'cek_reg',
'prodi_s2',
'pt_asal_s2',
'nisn',
'npsn',
'kebangsaan',
'ukuran_kaos',
'Tanggal_Lahir',
'status_ortu_ayah',
'status_ortu_ibu',
'Tanggal_Lulus',
'penghasilan_sampingan_ayah',
'penghasilan_sampingan_ibu',
'reg',
'Jenis_Kelamin',
'status_tinggal',
'prodi_asal',
'jumlah_tanggungan',
'jenjang',
'Angkatan',
'mhsAngk',
'IPS5',
'IPS6',
'total_kredit_capai_smt6 ',
'mhssmtanoin',
'mhssmtakls',
'mhssmtath',
'mhswaliprop',
'mhswalikab',
'tempat_lahir',
'mhskdtmplhrkab',
'mhstgllhr',
'mhskdtmplhrprop',
'penghasilan_ibu','penghasilan_ayah'
], axis=1, inplace=True)

# %%
dataset.head()
dataset.isnull().sum()
dataset = dataset.dropna(axis=0)

# %%
dataset.isnull().sum()
# Out:
# mhskdprop                   0
# mhskdkab                    0
# mhsjk                       0
# mhsstatrmh                  0
# mhswni                      0
# mhstextnoind                0
# mhsagama                    0
# mhskawin                    0
# mhshoby                     0
# mhsgoldarah                 0
# mhspdkayah                  0
# mhspdkibu                   0
# mhspekayah                  0
# mhspekibu                   0
# mhsjalurmsk                 0
# mhshubdgot                  0
# mhssmtaasal                 0
# mhssttbth                   0
# mhsebtamp                   0
# mhsebtanilai                0
# mhsthlhrayah                0
# mhsthlhribu                 0
# mhsbeasiswa                 0
# mhssmtajur                  0
# mhssmbbiaya                 0
# mhsprestasi                 0
# mhspemberibeasiswa          0
# total_kredit_capai          0
# mhs_smta_prop               0
# penghasilan_ibu_range       0
# penghasilan_ayah_range      0
# mhsgajiortu                 0
# penyakit_diderita           0
# kegiatan_mahasiswa          0
# kode                        0
# fakult                      0
# nama_prodi_asli             0
# IPS1                        0
# IPS2                        0
# IPS3                        0
# IPS4                        0
# total_kredit_capai_smt4     0
# ipk                         0
# class                       0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2467 entries, 0 to 2476
# Data columns (total 44 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   mhskdprop                 2467 non-null   int64
#  1   mhskdkab                  2467 non-null   int64
#  2   mhsjk                     2467 non-null   int64
#  3   mhsstatrmh                2467 non-null   int64
#  4   mhswni                    2467 non-null   int64
#  5   mhstextnoind              2467 non-null   int64
#  6   mhsagama                  2467 non-null   int64
#  7   mhskawin                  2467 non-null   int64
#  8   mhshoby                   2467 non-null   int64
#  9   mhsgoldarah               2467 non-null   int64
#  10  mhspdkayah                2467 non-null   int64
#  11  mhspdkibu                 2467 non-null   int64
#  12  mhspekayah                2467 non-null   int64
#  13  mhspekibu                 2467 non-null   int64
#  14  mhsjalurmsk               2467 non-null   int64
#  15  mhshubdgot                2467 non-null   int64
#  16  mhssmtaasal               2467 non-null   int64
#  17  mhssttbth                 2467 non-null   int64
#  18  mhsebtamp                 2467 non-null   int64
#  19  mhsebtanilai              2467 non-null   float64
#  20  mhsthlhrayah              2467 non-null   int64
#  21  mhsthlhribu               2467 non-null   int64
#  22  mhsbeasiswa               2467 non-null   int64
#  23  mhssmtajur                2467 non-null   int64
#  24  mhssmbbiaya               2467 non-null   int64
#  25  mhsprestasi               2467 non-null   int64
#  26  mhspemberibeasiswa        2467 non-null   int64
#  27  total_kredit_capai        2467 non-null   object
#  28  mhs_smta_prop             2467 non-null   int64
#  29  penghasilan_ibu_range     2467 non-null   int64
#  30  penghasilan_ayah_range    2467 non-null   int64
#  31  mhsgajiortu               2467 non-null   int64
#  32  penyakit_diderita         2467 non-null   object
#  33  kegiatan_mahasiswa        2467 non-null   object
#  34  kode                      2467 non-null   int64
#  35  fakult                    2467 non-null   int64
#  36  nama_prodi_asli           2467 non-null   object
#  37  IPS1                      2467 non-null   float64
#  38  IPS2                      2467 non-null   float64
#  39  IPS3                      2467 non-null   float64
#  40  IPS4                      2467 non-null   float64
#  41  total_kredit_capai_smt4   2467 non-null   float64
#  42  ipk                       2467 non-null   float64
#  43  class                     2467 non-null   int64
# dtypes: float64(7), int64(33), object(4)
# memory usage: 867.3+ KB

# %%
dataset.drop(['total_kredit_capai'], axis=1, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
dataset['penyakit_diderita']=lb.fit_transform(dataset['penyakit_diderita'])
dataset['kegiatan_mahasiswa']=lb.fit_transform(dataset['kegiatan_mahasiswa'])
dataset['nama_prodi_asli']=lb.fit_transform(dataset['nama_prodi_asli'])
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2467 entries, 0 to 2476
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   mhskdprop                 2467 non-null   int64
#  1   mhskdkab                  2467 non-null   int64
#  2   mhsjk                     2467 non-null   int64
#  3   mhsstatrmh                2467 non-null   int64
#  4   mhswni                    2467 non-null   int64
#  5   mhstextnoind              2467 non-null   int64
#  6   mhsagama                  2467 non-null   int64
#  7   mhskawin                  2467 non-null   int64
#  8   mhshoby                   2467 non-null   int64
#  9   mhsgoldarah               2467 non-null   int64
#  10  mhspdkayah                2467 non-null   int64
#  11  mhspdkibu                 2467 non-null   int64
#  12  mhspekayah                2467 non-null   int64
#  13  mhspekibu                 2467 non-null   int64
#  14  mhsjalurmsk               2467 non-null   int64
#  15  mhshubdgot                2467 non-null   int64
#  16  mhssmtaasal               2467 non-null   int64
#  17  mhssttbth                 2467 non-null   int64
#  18  mhsebtamp                 2467 non-null   int64
#  19  mhsebtanilai              2467 non-null   float64
#  20  mhsthlhrayah              2467 non-null   int64
#  21  mhsthlhribu               2467 non-null   int64
#  22  mhsbeasiswa               2467 non-null   int64
#  23  mhssmtajur                2467 non-null   int64
#  24  mhssmbbiaya               2467 non-null   int64
#  25  mhsprestasi               2467 non-null   int64
#  26  mhspemberibeasiswa        2467 non-null   int64
#  27  mhs_smta_prop             2467 non-null   int64
#  28  penghasilan_ibu_range     2467 non-null   int64
#  29  penghasilan_ayah_range    2467 non-null   int64
#  30  mhsgajiortu               2467 non-null   int64
#  31  penyakit_diderita         2467 non-null   int64
#  32  kegiatan_mahasiswa        2467 non-null   int64
#  33  kode                      2467 non-null   int64
#  34  fakult                    2467 non-null   int64
#  35  nama_prodi_asli           2467 non-null   int64
#  36  IPS1                      2467 non-null   float64
#  37  IPS2                      2467 non-null   float64
#  38  IPS3                      2467 non-null   float64
#  39  IPS4                      2467 non-null   float64
#  40  total_kredit_capai_smt4   2467 non-null   float64
#  41  ipk                       2467 non-null   float64
#  42  class                     2467 non-null   int64
# dtypes: float64(7), int64(36)
# memory usage: 848.0 KB

# %%
dataset.head(100)
# Out:
#      mhskdprop  mhskdkab  mhsjk  mhsstatrmh  mhswni  mhstextnoind  mhsagama  \
# 0           32     32036      1           1       1             2         1
# 1           33     33724      0           5       1             3         1
# 2           33     33113      0           1       1             3         1
# 3           33     33724      1           1       1             1         1
# 4           33     33191      0           1       1             2         1
# ..         ...       ...    ...         ...     ...           ...       ...
# 96          33     33225      0           1       1             3         1
# 97          33     33016      1           1       1             1         1
# 98          33     33121      1           1       1             3         1
# 100         33     33136      0           1       1             3         1
# 101         33     33105      1           1       1             1         1
#
#      mhskawin  mhshoby  mhsgoldarah  ...   kode  fakult  nama_prodi_asli  \
# 0           1        8            4  ...  60807       6                1
# 1           2        3            3  ...  87407       8               42
# 2           1        2            3  ...  10907       1               32
# 3           1        3            1  ...  20307       2               79
# 4           1        6            2  ...  20207       2               23
# ..        ...      ...          ...  ...    ...     ...              ...
# 96          1        1            3  ...  70107       7               85
# 97          1        1            2  ...  84607       8               52
# 98          1        1            2  ...  85607       8               53
# 100         1        8            4  ...  87107       8               50
# 101         1        1            3  ...  84607       8               52
#
#      IPS1  IPS2  IPS3  IPS4  total_kredit_capai_smt4    ipk  class
# 0    3.10  3.24  2.91  3.55                      83.0  3.19      0
# 1    3.08  3.57  3.00  3.04                      92.0  3.20      0
# 2    2.95  3.14  3.19  3.46                      86.0  3.23      0
# 3    2.45  0.71  3.00  3.34                      51.0  3.20      0
# 4    3.46  3.41  3.29  3.69                      88.0  3.49      0
# ..    ...   ...   ...   ...                       ...   ...    ...
# 96   3.40  3.50  2.96  3.34                      86.0  3.25      0
# 97   2.67  2.80  2.52  2.50                      70.0  2.78      0
# 98   3.22  3.58  2.91  3.72                      87.0  3.45      0
# 100  3.35  3.62  3.74  3.63                      93.0  3.56      0
# 101  2.62  2.60  3.00  3.02                      74.0  3.00      0
#
# [100 rows x 43 columns]

# %%
import numpy as np
from scipy.stats import entropy

features = dataset.columns.tolist()
features.remove('class')

#predictor
X = dataset[features]
# target
Y = dataset['class']

# menghitung entropy dari label kelas (Y)
def calc_entropy(labels):
    return entropy(np.bincount(labels))

# menghitung entropy dari atribut (x)   
def calc_entropy_attribute(X):
  return [calc_entropy(X[col]) for col in X.columns]


def calc_information_gain(X, Y):
    H_y = calc_entropy(Y)
    H_x = calc_entropy_attribute(X)
    ig = H_y - H_x
    return ig

# menghitung symmetrical uncertainty (SU)
def calc_su(X, Y):
    ig = calc_information_gain(X, Y)
    H_y = calc_entropy(Y)
    H_x = calc_entropy_attribute(X)
    su = 2 * ig / (H_x + H_y)
    return su

su = calc_su(X,Y)

for i in range(len(features)):
    print("SU of", features[i], ":", su[i])

# Ambil atribut dengan nilai SU > -0.06
selected_features = [features[i] for i in range(len(features)) if su[i] >= 0]
print(selected_features)
dataset[selected_features]
# Out:
# SU of mhskdprop : -1.170122284653025
# SU of mhskdkab : -1.7070002628090923
# SU of mhsjk : -0.8183245793458344
# SU of mhsstatrmh : -0.4374559336904276
# SU of mhswni : 1.6389728291611183
# SU of mhstextnoind : -1.204659126847688
# SU of mhsagama : -0.3800146026298822
# SU of mhskawin : 1.4706396507183315
# SU of mhshoby : -1.4255704087975614
# SU of mhsgoldarah : -1.2579199012445095
# SU of mhspdkayah : -1.439731334569686
# SU of mhspdkibu : -1.4312862803181317
# SU of mhspekayah : -1.5365927919657778
# SU of mhspekibu : -1.4324645551584054
# SU of mhsjalurmsk : -0.9598303023198586
# SU of mhshubdgot : 1.7122897602358216
# SU of mhssmtaasal : -1.824299030500557
# SU of mhssttbth : -0.3314971943901958
# SU of mhsebtamp : -0.2149430726485749
# SU of mhsebtanilai : -1.6724467630372641
# SU of mhsthlhrayah : -1.6634435900852111
# SU of mhsthlhribu : -1.6561556545358056
# SU of mhsbeasiswa : -0.8528152170409419
# SU of mhssmtajur : -1.0247120978325712
# SU of mhssmbbiaya : 0.02160558728933618
# SU of mhsprestasi : -1.2087513475835294
# SU of mhspemberibeasiswa : -0.8041889099546746
# SU of mhs_smta_prop : -1.1898017108172825
# SU of penghasilan_ibu_range : -1.3220768660095754
# SU of penghasilan_ayah_range : -1.4257987183324332
# SU of mhsgajiortu : -1.4266889780083545
# SU of penyakit_diderita : -1.1781735003837706
# SU of kegiatan_mahasiswa : -1.6990527116739147
# SU of kode : -1.7543949721280818
# SU of fakult : -1.4681020170695438
# SU of nama_prodi_asli : -1.7403290403789828
# SU of IPS1 : -0.5867464878122844
# SU of IPS2 : -0.6647540332089799
# SU of IPS3 : -0.5739106898147589
# SU of IPS4 : 0.03297815051781927
# SU of total_kredit_capai_smt4  : -1.6447109326626137
# SU of ipk : 0.3026624654471361
# ['mhswni', 'mhskawin', 'mhshubdgot', 'mhssmbbiaya', 'IPS4', 'ipk']
#       mhswni  mhskawin  mhshubdgot  mhssmbbiaya  IPS4   ipk
# 0          1         1           1            1  3.55  3.19
# 1          1         2           1            1  3.04  3.20
# 2          1         1           1            1  3.46  3.23
# 3          1         1           1            1  3.34  3.20
# 4          1         1           1            1  3.69  3.49
# ...      ...       ...         ...          ...   ...   ...
# 2472       1         1           1            1  3.14  2.56
# 2473       1         1           1            1  0.00  1.70
# 2474       1         1           1            1  3.75  3.51
# 2475       1         1           1            1  3.48  3.26
# 2476       1         1           1            1  3.49  3.43
#
# [2467 rows x 6 columns]

# %% [markdown]
# **SVM DENGAN FS**

# %%
# find best value of SVM's hyperparameter

from sklearn.model_selection import GridSearchCV
from sklearn import svm

# predictors
X = dataset[selected_features].to_numpy()
# target
Y = dataset['class'].to_numpy()

# define the range of hyperparameters to search over
param_grid = {
    'C': [0.1, 1, 10, 100],
    'gamma': [0.1, 1, 10, 100],
    'kernel': ['rbf','linear']
}

# create a SVM classifier object
svm_clf = svm.SVC()

# perform grid search with cross-validation
grid_search = GridSearchCV(svm_clf, param_grid, cv=5)
grid_search.fit(X, Y)

# print the best hyperparameters
print("Best hyperparameters:", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)
# Out:
# Best hyperparameters: {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# Best score:  0.9213638715293462

# %%
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn import svm
import time

# predictors
X = dataset[selected_features].to_numpy()
# target
Y = dataset['class'].to_numpy()

# get timing
t0 = time.time()
cv = KFold(n_splits=10, random_state=42, shuffle=True)

# run SVM with 10-fold cross validation
svc = svm.SVC(kernel='rbf', C=1, gamma=0.1, random_state=42)
y_pred = cross_val_predict(svc, X, Y, cv=cv)

print("Time: %.4f s\n"%(time.time() - t0))
# Calculate the confusion matrix
cm = confusion_matrix(Y, y_pred)
fig, ax = plt.subplots(figsize=(3, 3))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=10)
plt.ylabel('Actuals', fontsize=10)
plt.title('Confusion Matrix', fontsize=10)
plt.show()

# evaluate predictions using classification report
report = classification_report(Y, y_pred)
print(report)

print('\nAccuracy: %.2f%%' %(accuracy_score(Y, y_pred)*100))
print('Precision: %.2f%%' %(precision_score(Y, y_pred)*100))
print('Recall: %.2f%%' %(recall_score(Y, y_pred)*100))
# Out:
# Time: 0.5961 s
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      2262
#            1       1.00      0.05      0.09       205
#
#     accuracy                           0.92      2467
#    macro avg       0.96      0.52      0.53      2467
# weighted avg       0.93      0.92      0.89      2467
#
#
# Accuracy: 92.10%
# Precision: 100.00%
# Recall: 4.88%

# %% [markdown]
# **NAIVE BAYES DGN FS**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB

# predictors
X = dataset[selected_features].to_numpy()
# target
Y = dataset['class'].to_numpy()

# define the parameter grid
param_grid = {'var_smoothing': [1e-9, 1e-8, 1e-7, 1e-6, 1e-5]}

# create a GaussianNB classifier
gnb = GaussianNB(var_smoothing= 1e-05)

# create a GridSearchCV object
grid_search = GridSearchCV(gnb, param_grid=param_grid, cv=10)

# fit the GridSearchCV object to the data
grid_search.fit(X, Y)

# print the best parameters and score
print("Best parameters: ", grid_search.best_params_)
print("Best score: ", grid_search.best_score_)
# Out:
# Best parameters:  {'var_smoothing': 1e-05}
# Best score:  0.658592541391001

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import time

# predictors
X = dataset[selected_features].to_numpy()
# target
Y = dataset['class'].to_numpy()

# get timing
t0 = time.time()
cv = KFold(n_splits=10, random_state=42, shuffle=True)

# run Naive Bayes with 10-fold cross validation
gnb = GaussianNB(var_smoothing= 1e-05)
y_pred = cross_val_predict(gnb, X, Y, cv=cv)

print("Time: %.4f s\n"%(time.time() - t0))
# Calculate the confusion matrix
cm = confusion_matrix(Y, y_pred)
fig, ax = plt.subplots(figsize=(3, 3))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=10)
plt.ylabel('Actuals', fontsize=10)
plt.title('Confusion Matrix', fontsize=10)
plt.show()

# evaluate predictions using classification report
report = classification_report(Y, y_pred)
print(report)

print('\nAccuracy: %.2f%%' %(accuracy_score(Y, y_pred)*100))
print('Precision: %.2f%%' %(precision_score(Y, y_pred)*100))
print('Recall: %.2f%%' %(recall_score(Y, y_pred)*100))
# Out:
# Time: 0.0275 s
#               precision    recall  f1-score   support
#
#            0       0.94      0.70      0.80      2262
#            1       0.13      0.48      0.20       205
#
#     accuracy                           0.68      2467
#    macro avg       0.53      0.59      0.50      2467
# weighted avg       0.87      0.68      0.75      2467
#
#
# Accuracy: 68.10%
# Precision: 12.69%
# Recall: 48.29%

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# predictors
X = dataset[selected_features].to_numpy()
# target
Y = dataset['class'].to_numpy()

# create decision tree classifier
dt = DecisionTreeClassifier()

# set up parameter grid to search over
param_grid = {
    'max_depth': [2, 4, 6, 8, 10],
    'min_samples_split': [2, 4, 8, 16],
    'min_samples_leaf': [1, 2, 4, 8],
    'max_features': [None, 'sqrt', 'log2']
}

# perform grid search using cross-validation
cv = GridSearchCV(dt, param_grid, cv=10)
cv.fit(X, Y)

# print best hyperparameters
print(cv.best_params_)
print("Best score: ", cv.best_score_)
# Out:
# {'max_depth': 2, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 8}
# Best score:  0.922581547677825

# %%
#DECISION TREE

from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn import tree
import time

# predictors
X = dataset[selected_features].to_numpy()
# target
Y = dataset['class'].to_numpy()

# get timing
t0 = time.time()
cv = KFold(n_splits=10, random_state=42, shuffle=True)

# run DT with 10-fold cross validation
dt = tree.DecisionTreeClassifier(criterion="entropy",max_depth= 2, max_features= "sqrt", min_samples_leaf= 2,min_samples_split= 8)
y_pred = cross_val_predict(dt, X, Y, cv=cv)

print("Time: %.4f s\n"%(time.time() - t0))
# Calculate the confusion matrix
cm = confusion_matrix(Y, y_pred)
fig, ax = plt.subplots(figsize=(3, 3))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=10)
plt.ylabel('Actuals', fontsize=10)
plt.title('Confusion Matrix', fontsize=10)
plt.show()

# evaluate predictions using classification report
report = classification_report(Y, y_pred)
print(report)

print('\nAccuracy: %.2f%%' %(accuracy_score(Y, y_pred)*100))
print('Precision: %.2f%%' %(precision_score(Y, y_pred)*100))
print('Recall: %.2f%%' %(recall_score(Y, y_pred)*100))
# Out:
# Time: 0.0245 s
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      2262
#            1       0.73      0.04      0.07       205
#
#     accuracy                           0.92      2467
#    macro avg       0.82      0.52      0.52      2467
# weighted avg       0.90      0.92      0.88      2467
#
#
# Accuracy: 91.89%
# Precision: 72.73%
# Recall: 3.90%

# %% [markdown]
# **svm tanpa FS**

# %%
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn import svm
import time

# predictors
X = dataset[features].to_numpy()
# target
Y = dataset['class'].to_numpy()

# get timing
t0 = time.time()
cv = KFold(n_splits=10, random_state=42, shuffle=True)

# run DT with 10-fold cross validation
svc = svm.SVC(kernel='rbf', C=1, gamma=0.1, random_state=42)
y_pred = cross_val_predict(svc, X, Y, cv=cv)

print("Time: %.4f s\n"%(time.time() - t0))
# Calculate the confusion matrix
cm = confusion_matrix(Y, y_pred)
fig, ax = plt.subplots(figsize=(3, 3))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=10)
plt.ylabel('Actuals', fontsize=10)
plt.title('Confusion Matrix', fontsize=10)
plt.show()

# evaluate predictions using classification report
report = classification_report(Y, y_pred)
print(report)

print('\nAccuracy: %.2f%%' %(accuracy_score(Y, y_pred)*100))
print('Precision: %.2f%%' %(precision_score(Y, y_pred)*100))
print('Recall: %.2f%%' %(recall_score(Y, y_pred)*100))
# Out:
# Time: 4.3048 s
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      2262
#            1       0.00      0.00      0.00       205
#
#     accuracy                           0.92      2467
#    macro avg       0.46      0.50      0.48      2467
# weighted avg       0.84      0.92      0.88      2467
#
#
# Accuracy: 91.69%
# Precision: 0.00%
# Recall: 0.00%
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **NAIVE BAYES tanpa FS**

# %%
# predictors
X = dataset[features].to_numpy()
# target
Y = dataset['class'].to_numpy()

# get timing
t0 = time.time()
cv = KFold(n_splits=10, random_state=42, shuffle=True)

# run Naive Bayes with 10-fold cross validation
gnb = GaussianNB(var_smoothing= 1e-05)
y_pred = cross_val_predict(gnb, X, Y, cv=cv)

print("Time: %.4f s\n"%(time.time() - t0))
# Calculate the confusion matrix
cm = confusion_matrix(Y, y_pred)
fig, ax = plt.subplots(figsize=(3, 3))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=10)
plt.ylabel('Actuals', fontsize=10)
plt.title('Confusion Matrix', fontsize=10)
plt.show()

# evaluate predictions using classification report
report = classification_report(Y, y_pred)
print(report)

print('\nAccuracy: %.2f%%' %(accuracy_score(Y, y_pred)*100))
print('Precision: %.2f%%' %(precision_score(Y, y_pred)*100))
print('Recall: %.2f%%' %(recall_score(Y, y_pred)*100))
# Out:
# Time: 0.0415 s
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95      2262
#            1       0.12      0.04      0.06       205
#
#     accuracy                           0.90      2467
#    macro avg       0.52      0.51      0.50      2467
# weighted avg       0.85      0.90      0.87      2467
#
#
# Accuracy: 89.66%
# Precision: 12.12%
# Recall: 3.90%

# %% [markdown]
# **Decision tree tanpa FS**

# %%
from sklearn import tree

# predictors
X = dataset[features].to_numpy()
# target
Y = dataset['class'].to_numpy()

# get timing
t0 = time.time()
cv = KFold(n_splits=10, random_state=42, shuffle=True)

# run DT with 10-fold cross validation
dt = tree.DecisionTreeClassifier(criterion="entropy",max_depth= 2, max_features= "sqrt", min_samples_leaf= 2,min_samples_split= 8)
y_pred = cross_val_predict(dt, X, Y, cv=cv)

print("Time: %.4f s\n"%(time.time() - t0))
# Calculate the confusion matrix
cm = confusion_matrix(Y, y_pred)
fig, ax = plt.subplots(figsize=(3, 3))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=10)
plt.ylabel('Actuals', fontsize=10)
plt.title('Confusion Matrix', fontsize=10)
plt.show()

# evaluate predictions using classification report
report = classification_report(Y, y_pred)
print(report)

print('\nAccuracy: %.2f%%' %(accuracy_score(Y, y_pred)*100))
print('Precision: %.2f%%' %(precision_score(Y, y_pred)*100))
print('Recall: %.2f%%' %(recall_score(Y, y_pred)*100))
# Out:
# Time: 0.0707 s
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.96      2262
#            1       0.48      0.05      0.10       205
#
#     accuracy                           0.92      2467
#    macro avg       0.70      0.52      0.53      2467
# weighted avg       0.88      0.92      0.88      2467
#
#
# Accuracy: 91.65%
# Precision: 47.83%
# Recall: 5.37%

# %% [markdown]
# **USING SMOTE**

# %%
from imblearn.over_sampling import SMOTE

# %%
X = dataset.drop('class', axis=1)
y = dataset['class']

# Inisialisasi objek SMOTE
sm = SMOTE(random_state=42)

# Fit dan transform dataset dengan SMOTE
X_res, y_res = sm.fit_resample(X, y)

# %%
X_res
# Out:
#       mhskdprop  mhskdkab  mhsjk  mhsstatrmh  mhswni  mhstextnoind  mhsagama  \
# 0            32     32036      1           1       1             2         1
# 1            33     33724      0           5       1             3         1
# 2            33     33113      0           1       1             3         1
# 3            33     33724      1           1       1             1         1
# 4            33     33191      0           1       1             2         1
# ...         ...       ...    ...         ...     ...           ...       ...
# 4519         33     33114      0           1       1             3         1
# 4520         33     33113      0           1       1             3         1
# 4521         33     33134      0           1       1             2         1
# 4522         34     34025      1           1       1             3         1
# 4523         33     33099      1           1       1             3         1
#
#       mhskawin  mhshoby  mhsgoldarah  ...  kegiatan_mahasiswa   kode  fakult  \
# 0            1        8            4  ...                 813  60807       6
# 1            2        3            3  ...                 445  87407       8
# 2            1        2            3  ...                 425  10907       1
# 3            1        3            1  ...                 813  20307       2
# 4            1        6            2  ...                 484  20207       2
# ...        ...      ...          ...  ...                 ...    ...     ...
# 4519         1        3            3  ...                 119  60807       6
# 4520         1        1            3  ...                 722  84267       8
# 4521         1        1            2  ...                  32  40296       4
# 4522         1        1            2  ...                 556  74052       7
# 4523         1        1            3  ...                 813  84350       8
#
#       nama_prodi_asli      IPS1      IPS2      IPS3      IPS4  \
# 0                   1  3.100000  3.240000  2.910000  3.550000
# 1                  42  3.080000  3.570000  3.000000  3.040000
# 2                  32  2.950000  3.140000  3.190000  3.460000
# 3                  79  2.450000  0.710000  3.000000  3.340000
# 4                  23  3.460000  3.410000  3.290000  3.690000
# ...               ...       ...       ...       ...       ...
# 4519                1  3.340062  3.297980  3.334511  3.487286
# 4520               38  3.415379  3.443362  3.111596  3.532354
# 4521                6  3.495731  3.569731  3.595750  3.515615
# 4522               32  2.363741  2.837623  2.532617  2.805714
# 4523               49  3.229546  3.046463  3.345114  3.221051
#
#       total_kredit_capai_smt4        ipk
# 0                    83.000000  3.190000
# 1                    92.000000  3.200000
# 2                    86.000000  3.230000
# 3                    51.000000  3.200000
# 4                    88.000000  3.490000
# ...                        ...       ...
# 4519                 90.000000  3.417286
# 4520                 91.949583  3.377479
# 4521                 89.671153  3.523288
# 4522                 68.728466  3.040338
# 4523                 89.744322  3.163907
#
# [4524 rows x 42 columns]

# %%
# Periksa hasil dari SMOTE
print('Jumlah sampel asli:', len(dataset))
print('Jumlah sampel setelah SMOTE:', len(X_res))
print('Jumlah sampel target = 0:', sum(y_res == 0))
print('Jumlah sampel target = 1:', sum(y_res == 1))
# Out:
# Jumlah sampel asli: 2467
# Jumlah sampel setelah SMOTE: 4524
# Jumlah sampel target = 0: 2262
# Jumlah sampel target = 1: 2262

# %%
# predictors
X = X_res.to_numpy()
# target
Y = y_res.to_numpy()

# get timing
t0 = time.time()
cv = KFold(n_splits=10, random_state=42, shuffle=True)

# run SVM with 10-fold cross validation
svc = svm.SVC(kernel='rbf', C=1, gamma=0.1, random_state=42)
y_pred = cross_val_predict(svc, X, Y, cv=cv)

print("Time: %.4f s\n"%(time.time() - t0))
# Calculate the confusion matrix
cm = confusion_matrix(Y, y_pred)
fig, ax = plt.subplots(figsize=(3, 3))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=10)
plt.ylabel('Actuals', fontsize=10)
plt.title('Confusion Matrix', fontsize=10)
plt.show()


# evaluate predictions using classification report
report = classification_report(Y, y_pred)
print(report)

print('\nAccuracy: %.2f%%' %(accuracy_score(Y, y_pred)*100))
print('Precision: %.2f%%' %(precision_score(Y, y_pred)*100))
print('Recall: %.2f%%' %(recall_score(Y, y_pred)*100))
# Out:
# Time: 16.7993 s
#               precision    recall  f1-score   support
#
#            0       0.49      0.58      0.53      2262
#            1       0.48      0.40      0.44      2262
#
#     accuracy                           0.49      4524
#    macro avg       0.49      0.49      0.48      4524
# weighted avg       0.49      0.49      0.48      4524
#
#
# Accuracy: 48.72%
# Precision: 48.43%
# Recall: 39.61%

# %%
# predictors
X = X_res.to_numpy()
# target
Y = y_res.to_numpy()

# get timing
t0 = time.time()
cv = KFold(n_splits=10, random_state=42, shuffle=True)

# run Naive Bayes with 10-fold cross validation
gnb = GaussianNB(var_smoothing=1e-05)
y_pred = cross_val_predict(gnb, X, Y, cv=cv)

print("Time: %.4f s\n"%(time.time() - t0))
# Calculate the confusion matrix
cm = confusion_matrix(Y, y_pred)
fig, ax = plt.subplots(figsize=(3, 3))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=10)
plt.ylabel('Actuals', fontsize=10)
plt.title('Confusion Matrix', fontsize=10)
plt.show()

# evaluate predictions using classification report
report = classification_report(Y, y_pred)
print(report)

print('\nAccuracy: %.2f%%' %(accuracy_score(Y, y_pred)*100))
print('Precision: %.2f%%' %(precision_score(Y, y_pred)*100))
print('Recall: %.2f%%' %(recall_score(Y, y_pred)*100))
# Out:
# Time: 0.0585 s
#               precision    recall  f1-score   support
#
#            0       0.50      0.96      0.66      2262
#            1       0.54      0.05      0.08      2262
#
#     accuracy                           0.50      4524
#    macro avg       0.52      0.50      0.37      4524
# weighted avg       0.52      0.50      0.37      4524
#
#
# Accuracy: 50.33%
# Precision: 53.97%
# Recall: 4.51%

# %%
# predictors
X = X_res.to_numpy()
# target
Y = y_res.to_numpy()

# get timing
t0 = time.time()
cv = KFold(n_splits=10, random_state=42, shuffle=True)

# run DT with 10-fold cross validation
dt = tree.DecisionTreeClassifier(criterion="entropy",max_depth= 2, max_features= "sqrt", min_samples_leaf= 2,min_samples_split= 8)
y_pred = cross_val_predict(dt, X, Y, cv=cv)

print("Time: %.4f s\n"%(time.time() - t0))
# Calculate the confusion matrix
cm = confusion_matrix(Y, y_pred)
fig, ax = plt.subplots(figsize=(3, 3))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=10)
plt.ylabel('Actuals', fontsize=10)
plt.title('Confusion Matrix', fontsize=10)
plt.show()

# evaluate predictions using classification report
report = classification_report(Y, y_pred)
print(report)

print('\nAccuracy: %.2f%%' %(accuracy_score(Y, y_pred)*100))
print('Precision: %.2f%%' %(precision_score(Y, y_pred)*100))
print('Recall: %.2f%%' %(recall_score(Y, y_pred)*100))
# Out:
# Time: 0.1997 s
#               precision    recall  f1-score   support
#
#            0       0.65      0.65      0.65      2262
#            1       0.65      0.65      0.65      2262
#
#     accuracy                           0.65      4524
#    macro avg       0.65      0.65      0.65      4524
# weighted avg       0.65      0.65      0.65      4524
#
#
# Accuracy: 65.03%
# Precision: 64.96%
# Recall: 65.25%

# %% [markdown]
# **SMOTE FS**

# %%
X = dataset[selected_features]
y = dataset['class']

# Inisialisasi objek SMOTE
sm = SMOTE(random_state=42)

# Fit dan transform dataset dengan SMOTE
X_res1, y_res1 = sm.fit_resample(X, y)

X_res1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4524 entries, 0 to 4523
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mhswni       4524 non-null   int64
#  1   mhskawin     4524 non-null   int64
#  2   mhshubdgot   4524 non-null   int64
#  3   mhssmbbiaya  4524 non-null   int64
#  4   IPS4         4524 non-null   float64
#  5   ipk          4524 non-null   float64
# dtypes: float64(2), int64(4)
# memory usage: 212.2 KB

# %% [markdown]
# **MODEL MENGGUNAKAN FS SETELAH OVERSAMPLING SMOTE**

# %%
# predictors
X = X_res1.to_numpy()
# target
Y = y_res1.to_numpy()

# get timing
t0 = time.time()
cv = KFold(n_splits=10, random_state=42, shuffle=True)

# run SVM with 10-fold cross validation
svc = svm.SVC(kernel='rbf', C=1, gamma=0.1, random_state=42)
y_pred = cross_val_predict(svc, X, Y, cv=cv)

print("Time: %.4f s\n"%(time.time() - t0))
# Calculate the confusion matrix
cm = confusion_matrix(Y, y_pred)
fig, ax = plt.subplots(figsize=(3, 3))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=10)
plt.ylabel('Actuals', fontsize=10)
plt.title('Confusion Matrix', fontsize=10)
plt.show()

# evaluate predictions using classification report
report = classification_report(Y, y_pred)
print(report)

print('\nAccuracy: %.2f%%' %(accuracy_score(Y, y_pred)*100))
print('Precision: %.2f%%' %(precision_score(Y, y_pred)*100))
print('Recall: %.2f%%' %(recall_score(Y, y_pred)*100))
# Out:
# Time: 9.1001 s
#               precision    recall  f1-score   support
#
#            0       0.61      0.77      0.68      2262
#            1       0.69      0.51      0.59      2262
#
#     accuracy                           0.64      4524
#    macro avg       0.65      0.64      0.63      4524
# weighted avg       0.65      0.64      0.63      4524
#
#
# Accuracy: 64.12%
# Precision: 69.24%
# Recall: 50.84%

# %%
# predictors
X = X_res1.to_numpy()
# target
Y = y_res1.to_numpy()

# get timing
t0 = time.time()
cv = KFold(n_splits=10, random_state=42, shuffle=True)

# run Naive Bayes with 10-fold cross validation
gnb = GaussianNB(var_smoothing= 1e-05)
y_pred = cross_val_predict(gnb, X, Y, cv=cv)

print("Time: %.4f s\n"%(time.time() - t0))
# Calculate the confusion matrix
cm = confusion_matrix(Y, y_pred)
fig, ax = plt.subplots(figsize=(3, 3))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=10)
plt.ylabel('Actuals', fontsize=10)
plt.title('Confusion Matrix', fontsize=10)
plt.show()

# evaluate predictions using classification report
report = classification_report(Y, y_pred)
print(report)

print('\nAccuracy: %.2f%%' %(accuracy_score(Y, y_pred)*100))
print('Precision: %.2f%%' %(precision_score(Y, y_pred)*100))
print('Recall: %.2f%%' %(recall_score(Y, y_pred)*100))
# Out:
# Time: 0.0604 s
#               precision    recall  f1-score   support
#
#            0       0.71      0.01      0.03      2262
#            1       0.50      0.99      0.67      2262
#
#     accuracy                           0.50      4524
#    macro avg       0.61      0.50      0.35      4524
# weighted avg       0.61      0.50      0.35      4524
#
#
# Accuracy: 50.40%
# Precision: 50.20%
# Recall: 99.47%

# %%
# predictors
X = X_res1.to_numpy()
# target
Y = y_res1.to_numpy()

# get timing
t0 = time.time()
cv = KFold(n_splits=10, random_state=42, shuffle=True)

# run DT with 10-fold cross validation
dt = tree.DecisionTreeClassifier(criterion="entropy",max_depth= 2, max_features= "sqrt", min_samples_leaf= 2,min_samples_split= 8)
y_pred = cross_val_predict(dt, X, Y, cv=cv)

print("Time: %.4f s\n"%(time.time() - t0))
# Calculate the confusion matrix
cm = confusion_matrix(Y, y_pred)
fig, ax = plt.subplots(figsize=(3, 3))
ax.matshow(cm, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=10)
plt.ylabel('Actuals', fontsize=10)
plt.title('Confusion Matrix', fontsize=10)
plt.show()

# evaluate predictions using classification report
report = classification_report(Y, y_pred)
print(report)

print('\nAccuracy: %.2f%%' %(accuracy_score(Y, y_pred)*100))
print('Precision: %.2f%%' %(precision_score(Y, y_pred)*100))
print('Recall: %.2f%%' %(recall_score(Y, y_pred)*100))
# Out:
# Time: 0.1226 s
#               precision    recall  f1-score   support
#
#            0       0.58      0.56      0.57      2262
#            1       0.57      0.59      0.58      2262
#
#     accuracy                           0.57      4524
#    macro avg       0.57      0.57      0.57      4524
# weighted avg       0.57      0.57      0.57      4524
#
#
# Accuracy: 57.40%
# Precision: 57.17%
# Recall: 59.02%
